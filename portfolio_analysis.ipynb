# %%
# Install yfinance and matplotlib package
# !pip install yfinance
# !pip install matplotlib

# %%
# Import yfinance and matplotlib
import yfinance as yf  
import matplotlib.pyplot as plt
import seaborn as sb
# Load Packages
import numpy as np
import pandas as pd
from pandas_datareader import data

# %% [markdown]
# # Step 1: Choose seven (7) assets (preferably something with significant historical data)

# %%
# Read Data
test = data.DataReader(['SPY', 'AAPL','MSFT','TSLA','JNJ','UNH','NVDA'], 'yahoo', start='2020-07-01', end='2022-07-01')
test.head()
# Out:
# Attributes   Adj Close                                                 \
# Symbols            SPY       AAPL        MSFT        TSLA         JNJ
# Date
# 2020-06-30  299.575195  90.074974  199.925888  215.962006  133.604034
# 2020-07-01  301.673615  89.904610  201.094925  223.925995  133.366531
# 2020-07-02  303.334930  89.904610  202.627457  241.731995  133.927048
# 2020-07-06  308.017609  92.309570  206.989273  274.316010  135.836639
# 2020-07-07  304.840698  92.023155  204.582428  277.971985  135.713104
#
# Attributes                              Close                         ...  \
# Symbols            UNH       NVDA         SPY       AAPL        MSFT  ...
# Date                                                                  ...
# 2020-06-30  286.754120  94.802025  308.359985  91.199997  203.509995  ...
# 2020-07-01  289.456940  95.123924  310.519989  91.027496  204.699997  ...
# 2020-07-02  289.972198  95.944901  312.230011  91.027496  206.259995  ...
# 2020-07-06  294.395782  98.210716  317.049988  93.462502  210.699997  ...
# 2020-07-07  288.406891  98.535110  313.779999  93.172501  208.250000  ...
#
# Attributes        Open                              Volume               \
# Symbols            JNJ         UNH       NVDA          SPY         AAPL
# Date
# 2020-06-30  139.399994  288.570007  93.139999  113394800.0  140223200.0
# 2020-07-01  140.690002  295.829987  95.207497   72396500.0  110737200.0
# 2020-07-02  141.250000  300.500000  96.389999   69344200.0  114041600.0
# 2020-07-06  142.169998  303.000000  97.417503   61713800.0  118655600.0
# 2020-07-07  141.389999  300.660004  99.462502   82910000.0  112424400.0
#
# Attributes
# Symbols           MSFT         TSLA        JNJ        UNH        NVDA
# Date
# 2020-06-30  34310300.0   84592500.0  7738300.0  2932900.0  36789200.0
# 2020-07-01  32061200.0   66634500.0  6174800.0  2303800.0  32664800.0
# 2020-07-02  29315800.0   86250500.0  5152200.0  1971700.0  36405600.0
# 2020-07-06  31897600.0  102849500.0  6156400.0  2395000.0  31589200.0
# 2020-07-07  33600700.0  107448500.0  5622600.0  2075700.0  35780000.0
#
# [5 rows x 42 columns]

# %% [markdown]
# # Step 2: Retrieve daily open or close data on your assets for the previous 2 years

# %%
data_open=test['Open']
data_open.head()
# Out:
# Symbols            SPY       AAPL        MSFT        TSLA         JNJ  \
# Date
# 2020-06-30  303.989990  90.019997  197.880005  201.300003  139.399994
# 2020-07-01  309.570007  91.279999  203.139999  216.600006  140.690002
# 2020-07-02  314.239990  91.962502  205.679993  244.296005  141.250000
# 2020-07-06  316.369995  92.500000  208.830002  255.337997  142.169998
# 2020-07-07  315.380005  93.852501  210.449997  281.002014  141.389999
#
# Symbols            UNH       NVDA
# Date
# 2020-06-30  288.570007  93.139999
# 2020-07-01  295.829987  95.207497
# 2020-07-02  300.500000  96.389999
# 2020-07-06  303.000000  97.417503
# 2020-07-07  300.660004  99.462502

# %%
data_open.plot()
plt.show()

# %%
data_close=test['Close']
data_close.head()
# Out:
# Symbols            SPY       AAPL        MSFT        TSLA         JNJ  \
# Date
# 2020-06-30  308.359985  91.199997  203.509995  215.962006  140.630005
# 2020-07-01  310.519989  91.027496  204.699997  223.925995  140.380005
# 2020-07-02  312.230011  91.027496  206.259995  241.731995  140.970001
# 2020-07-06  317.049988  93.462502  210.699997  274.316010  142.979996
# 2020-07-07  313.779999  93.172501  208.250000  277.971985  142.850006
#
# Symbols            UNH       NVDA
# Date
# 2020-06-30  294.950012  94.977501
# 2020-07-01  297.730011  95.300003
# 2020-07-02  298.260010  96.122498
# 2020-07-06  302.809998  98.392502
# 2020-07-07  296.649994  98.717499

# %%
data_close.plot()
plt.show()

# %%
# Closing price
test = test['Adj Close']
test.head()
# Out:
# Symbols            SPY       AAPL        MSFT        TSLA         JNJ  \
# Date
# 2020-06-30  299.575134  90.074982  199.925919  215.962006  133.604034
# 2020-07-01  301.673615  89.904594  201.094910  223.925995  133.366531
# 2020-07-02  303.334961  89.904594  202.627457  241.731995  133.927063
# 2020-07-06  308.017578  92.309578  206.989273  274.316010  135.836624
# 2020-07-07  304.840759  92.023155  204.582428  277.971985  135.713135
#
# Symbols            UNH       NVDA
# Date
# 2020-06-30  286.754150  94.802017
# 2020-07-01  289.456879  95.123924
# 2020-07-02  289.972198  95.944901
# 2020-07-06  294.395782  98.210716
# 2020-07-07  288.406891  98.535118

# %% [markdown]
# # Step 3: Calculate the mean, variance, and correlation matrix for all assets

# %%
# Log of percentage change
tesla = test.pct_change().apply(lambda x: np.log(1+x))
tesla.head()
# Out:
# Symbols          SPY      AAPL      MSFT      TSLA       JNJ       UNH  \
# Date
# 2020-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-07-01  0.006980 -0.001893  0.005830  0.036213 -0.001779  0.009381
# 2020-07-02  0.005492  0.000000  0.007592  0.076514  0.004194  0.001779
# 2020-07-06  0.015319  0.026399  0.021298  0.126451  0.014158  0.015140
# 2020-07-07 -0.010367 -0.003108 -0.011696  0.013240 -0.000910 -0.020552
#
# Symbols         NVDA
# Date
# 2020-06-30       NaN
# 2020-07-01  0.003390
# 2020-07-02  0.008593
# 2020-07-06  0.023341
# 2020-07-07  0.003298

# %%
var_tesla = tesla.var()
var_tesla
# Out:
# Symbols
# SPY     0.000124
# AAPL    0.000410
# MSFT    0.000304
# TSLA    0.001762
# JNJ     0.000105
# UNH     0.000204
# NVDA    0.001033
# dtype: float64

# %%
# Volatility
tesla_vol = np.sqrt(var_tesla * 250)

tesla_vol
# Out:
# Symbols
# SPY     0.176232
# AAPL    0.320006
# MSFT    0.275544
# TSLA    0.663637
# JNJ     0.162112
# UNH     0.225650
# NVDA    0.508132
# dtype: float64

# %%
test.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250)).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Symbols'>

# %%
# Log of Percentage change
test1 = test.pct_change().apply(lambda x: np.log(1+x))
test1.head()
# Out:
# Symbols          SPY      AAPL      MSFT      TSLA       JNJ       UNH  \
# Date
# 2020-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-07-01  0.006980 -0.001893  0.005830  0.036213 -0.001779  0.009381
# 2020-07-02  0.005492  0.000000  0.007592  0.076514  0.004194  0.001779
# 2020-07-06  0.015319  0.026399  0.021298  0.126451  0.014158  0.015140
# 2020-07-07 -0.010367 -0.003108 -0.011696  0.013240 -0.000910 -0.020552
#
# Symbols         NVDA
# Date
# 2020-06-30       NaN
# 2020-07-01  0.003390
# 2020-07-02  0.008593
# 2020-07-06  0.023341
# 2020-07-07  0.003298

# %%
dataplot = sb.heatmap(test1.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %% [markdown]
# # Step 4: Calculate efficient frontier and optimal weights for your portfolio (Don’t forget the output!)

# %% [markdown]
# test2 = test.pct_change().apply(lambda x: np.log(1+x))
# test2.head()

# %%
# Define weights for allocation
w = [0.2, 0.8,0.3,0.5,0.2, 0.3,0.2]
e_r_ind = test2.mean()
e_r_ind
# Out:
# Symbols
# SPY     0.000477
# AAPL    0.000858
# MSFT    0.000517
# TSLA    0.002276
# JNJ     0.000585
# UNH     0.001169
# NVDA    0.000845
# dtype: float64

# %%
# Total expected return
e_r = (e_r_ind*w).sum()
e_r
# Out:
# 0.0027118100376533876

# %% [markdown]
# # Step 5: Use MatPlotLib or Seaborn libraries to graph the results (matrix and frontier)Step 6: Output the calculated optimal weighting (identify portfolio weightings for optimum Sharpe Ratio)along with the efficient frontier and correlation matrix charts. Output to a saved file.

# %%
# Import data
df = yf.download(['SPY', 'AAPL','MSFT','TSLA','JNJ','UNH','NVDA'],'2020-07-01','2022-07-01')
df.head()
# Out:
# [*********************100%***********************]  7 of 7 completed
#             Adj Close                                                 \
#                  AAPL         JNJ        MSFT       NVDA         SPY
# Date
# 2020-06-30  90.074982  133.604050  199.925858  94.802032  299.575134
# 2020-07-01  89.904602  133.366547  201.094940  95.123924  301.673615
# 2020-07-02  89.904602  133.927063  202.627472  95.944908  303.334930
# 2020-07-06  92.309578  135.836624  206.989258  98.210716  308.017609
# 2020-07-07  92.023155  135.713135  204.582428  98.535110  304.840729
#
#                                         Close                          ...  \
#                   TSLA         UNH       AAPL         JNJ        MSFT  ...
# Date                                                                   ...
# 2020-06-30  215.962006  286.754150  91.199997  140.630005  203.509995  ...
# 2020-07-01  223.925995  289.456879  91.027496  140.380005  204.699997  ...
# 2020-07-02  241.731995  289.972168  91.027496  140.970001  206.259995  ...
# 2020-07-06  274.316010  294.395752  93.462502  142.979996  210.699997  ...
# 2020-07-07  277.971985  288.406921  93.172501  142.850006  208.250000  ...
#
#                   Open                             Volume                     \
#                    SPY        TSLA         UNH       AAPL      JNJ      MSFT
# Date
# 2020-06-30  303.989990  201.300003  288.570007  140223200  7738300  34310300
# 2020-07-01  309.570007  216.600006  295.829987  110737200  6174800  32061200
# 2020-07-02  314.239990  244.296005  300.500000  114041600  5152200  29315800
# 2020-07-06  316.369995  255.337997  303.000000  118655600  6156400  31897600
# 2020-07-07  315.380005  281.002014  300.660004  112424400  5622600  33600700
#
#
#                 NVDA        SPY       TSLA      UNH
# Date
# 2020-06-30  36789200  113394800   84592500  2932900
# 2020-07-01  32664800   72396500   66634500  2303800
# 2020-07-02  36405600   69344200   86250500  1971700
# 2020-07-06  31589200   61713800  102849500  2395000
# 2020-07-07  35780000   82910000  107448500  2075700
#
# [5 rows x 42 columns]

# %%
# Closing price
df = df['Adj Close']
df.head()
# Out:
#                  AAPL         JNJ        MSFT       NVDA         SPY  \
# Date
# 2020-06-30  90.074982  133.604050  199.925858  94.802032  299.575134
# 2020-07-01  89.904602  133.366547  201.094940  95.123924  301.673615
# 2020-07-02  89.904602  133.927063  202.627472  95.944908  303.334930
# 2020-07-06  92.309578  135.836624  206.989258  98.210716  308.017609
# 2020-07-07  92.023155  135.713135  204.582428  98.535110  304.840729
#
#                   TSLA         UNH
# Date
# 2020-06-30  215.962006  286.754150
# 2020-07-01  223.925995  289.456879
# 2020-07-02  241.731995  289.972168
# 2020-07-06  274.316010  294.395752
# 2020-07-07  277.971985  288.406921

# %%
# Log of percentage change
cov_matrix = df.pct_change().apply(lambda x: np.log(1+x)).cov()
corr_matrix = df.pct_change().apply(lambda x: np.log(1+x)).corr()
# Randomly weighted portfolio's variance
w = {'SPY':0.2, 'AAPL':0.3,'MSFT':0.1,'TSLA':0.4,'JNJ':0.3,'UNH':0.2,'NVDA':0.5}
port_var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()

# %%
ind_er = df.resample('Y').last().pct_change().mean()
ind_er
# Out:
# AAPL    0.059273
# JNJ     0.082699
# MSFT    0.145889
# NVDA    0.385218
# SPY     0.043737
# TSLA    0.067397
# UNH     0.240802
# dtype: float64

# %%
# Portfolio returns
w = [0.2, 0.8,0.3,0.5,0.2, 0.3,0.2]
port_er = (w*ind_er).sum()
port_er
# Out:
# 0.3915164732688933

# %%
# Volatility is given by the annual standard deviation. We multiply by 250 because there are 250 trading days/year.
ann_sd = df.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
ann_sd
# Out:
# AAPL    0.320145
# JNJ     0.162098
# MSFT    0.275725
# NVDA    0.507701
# SPY     0.176264
# TSLA    0.664258
# UNH     0.225832
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#        Returns  Volatility
# AAPL  0.059273    0.320145
# JNJ   0.082699    0.162098
# MSFT  0.145889    0.275725
# NVDA  0.385218    0.507701
# SPY   0.043737    0.176264
# TSLA  0.067397    0.664258
# UNH   0.240802    0.225832

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(df.columns)
num_portfolios = 10000
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(df.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios  = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#     Returns  Volatility  AAPL weight  JNJ weight  MSFT weight  NVDA weight  \
# 0  0.126613    0.181403     0.144533    0.327351     0.025142     0.059853
# 1  0.125170    0.265128     0.147876    0.108286     0.197995     0.078200
# 2  0.143676    0.282478     0.047379    0.033835     0.272522     0.071394
# 3  0.118523    0.205177     0.206478    0.321895     0.000813     0.085999
# 4  0.138625    0.215055     0.019259    0.189510     0.226067     0.096645
#
#    SPY weight  TSLA weight  UNH weight
# 0    0.157591     0.065733    0.219797
# 1    0.155413     0.193432    0.118798
# 2    0.131616     0.240385    0.202870
# 3    0.145128     0.101769    0.137919
# 4    0.222647     0.100016    0.145856

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[10,10])
# Out:
# <AxesSubplot:xlabel='Volatility', ylabel='Returns'>

# %%
#Efficient Frontlier
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns        0.109056
# Volatility     0.157506
# AAPL weight    0.045213
# JNJ weight     0.320832
# MSFT weight    0.049784
# NVDA weight    0.002241
# SPY weight     0.317017
# TSLA weight    0.034253
# UNH weight     0.230659
# Name: 8715, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Volatility']).idxmax()]
optimal_risky_port
# Out:
# Returns        0.201469
# Volatility     0.194841
# AAPL weight    0.010856
# JNJ weight     0.111127
# MSFT weight    0.100914
# NVDA weight    0.038454
# SPY weight     0.042649
# TSLA weight    0.042462
# UNH weight     0.653536
# Name: 5373, dtype: float64

# %%
# Plotting optimal portfolio
plt.subplots(figsize=(10, 10))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
